# %%
import cv2
import pickle
import numpy as np
from matplotlib import pyplot as plt
from utils.extract_features import getImages
from utils.plot_stuff import plot_images, plot_hha_components, plot_angle_directions, plot_masks, plot_selected_regions_together

# %%
imagenumber = 20

# %%
image, image_depth, image_hha, image_xyz, image_labinsts, allmasks, am_label, am_instance, am_bbox = (
    getImages(f"{imagenumber}")
)

# %%
plot_images(image, image_depth, image_hha)

# %%
plot_hha_components(image_hha)

# %%
plot_angle_directions(image_hha)

# %%
plot_masks(allmasks, am_label, am_instance)

# %%
X, Y = pickle.load(open(f"../nyudv2/regions/{imagenumber}.p", 'rb'))
bboxes = X[:, 2:6].astype(int)
plot_selected_regions_together(image, bboxes, Y)
